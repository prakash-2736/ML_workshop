# %% [markdown]
# <a href="https://colab.research.google.com/github/prakash-2736/ML_workshop/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1
# Create a Pandas DataFrame from the following dictionary: data = { 'Name': ['Alice', 'Bob', 'Carol'], 'Age': [24, 27, 22], 'Salary': [50000, 55000, 48000] } • Add a new column called Bonus which is 10% of the salary.

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Carol'],
    'Age': [24, 27, 22],
    'Salary': [50000, 55000, 48000]
}
df = pd.DataFrame(data)

df['Bonus'] = df['Salary'] * 0.10
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# 2. Given the DataFrame created in the above question
#
# • Display the first two rows. • Compute the mean salary.

# %%
df.head(2)
mean_salary = df['Salary'].mean()
print(mean_salary)
# Out:
# 51000.0

# %% [markdown]
# 3.Using the same DataFrame: • Extract all rows where the Age is greater than 25. • Filter out rows where the Salary is less than 50000.

# %%
df[df['Age'] > 25]
df[df['Salary'] >= 50000]
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# 4.Create the following DataFrame: data = { 'A': [1, 2, None, 4], 'B': [None, 2, 3, None], 'C': [1, 2, 3, 4] } df = pd.DataFrame(data) • Fill missing values in column A with the mean of the column. • Drop rows where all values are None.

# %%
data = {
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, None],
    'C': [1, 2, 3, 4]
}
df_missing = pd.DataFrame(data)


df_missing['A'] = df_missing['A'].fillna(df_missing['A'].mean())


df_missing = df_missing.dropna(how='all')

print(df_missing)
# Out:
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# 5.Create a DataFrame for employees: data = { 'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'], 'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'], 'Salary': [50000, 45000, 60000, 65000, 70000] } • Group the data by Department and compute the total and mean salary for each department.

# %%
import pandas as pd
data = {
 'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
 'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
 'Salary': [50000, 45000, 60000, 65000, 70000]
}
df = pd.DataFrame(data)
department_stats = df.groupby('Department')['Salary'].agg(['sum', 'mean'])
department_stats
# Out:
#                sum     mean
# Department
# Finance      70000  70000.0
# HR           95000  47500.0
# IT          125000  62500.0

# %% [markdown]
# 6.Given two DataFrames: df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']}) df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]}) • Perform an inner join on the ID column

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})

merged_df = pd.merge(df1, df2, on='ID', how='inner')
merged_df
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# 7.Given a small dataset, clean and display basic
# statistics using Pandas.

# %%
data = {
    'Value1': [10, 20, None, 40, 50],
    'Value2': [None, 25, 35, None, 55]
}
df_clean = pd.DataFrame(data)


df_clean = df_clean.fillna(df_clean.mean())


print(df_clean.describe())
# Out:
#           Value1     Value2
# count   5.000000   5.000000
# mean   30.000000  38.333333
# std    15.811388  10.801234
# min    10.000000  25.000000
# 25%    20.000000  35.000000
# 50%    30.000000  38.333333
# 75%    40.000000  38.333333
# max    50.000000  55.000000

# %% [markdown]
# 8.small EDA task • Load the Titanic dataset (titanic.csv) into a Pandas DataFrame. • Perform the following tasks: o Display the number of missing values in each column. o Find the average age of passengers. o Create a bar plot to show the survival rate based on gender.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_titanic = pd.read_csv('/content/Titanic-Dataset.csv')


print("Missing Values:\n", df_titanic.isnull().sum())


average_age = df_titanic['Age'].mean()
print("Average Age:", average_age)


sns.barplot(x='Sex', y='Survived', data=df_titanic)
plt.title("Survival Rate by Gender")
plt.show()
# Out:
# Missing Values:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Average Age: 29.69911764705882

# %% [markdown]
# 9..Data Transformation • Load a dataset containing daily temperatures and dates. Perform the following: o Convert the date column into a DateTime object. o Create a new column that categorizes temperatures into High, Medium, or Low.

# %%
import pandas as pd


data = {
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
    'Temperature': [15, 25, 35, 18]
}
df_temp = pd.DataFrame(data)


df_temp['Date'] = pd.to_datetime(df_temp['Date'])

def categorize_temp(temp):
    if temp > 30:
        return 'High'
    elif 20 <= temp <= 30:
        return 'Medium'
    else:
        return 'Low'

df_temp['Category'] = df_temp['Temperature'].apply(categorize_temp)

print(df_temp)
# Out:
#         Date  Temperature Category
# 0 2023-01-01           15      Low
# 1 2023-01-02           25   Medium
# 2 2023-01-03           35     High
# 3 2023-01-04           18      Low
